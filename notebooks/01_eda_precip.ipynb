# %% [markdown]
# # 01 — Exploratory Data Analysis: Precipitation
#
# **Owner:** Tiffany
#
# **Purpose:** Explore the distribution of total precipitation across the study domain. Visualise seasonal cycles, identify extreme-event climatology, and plot domain maps to confirm spatial coverage and data integrity.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path('..') / 'src'))

from causal_precip import load_config
import pprint

cfg = load_config()
pprint.pprint(cfg)

# %%
import warnings

raw_path = Path('..') / cfg['paths']['raw_data']
processed_path = Path('..') / cfg['paths']['processed']

for p in [raw_path, processed_path]:
    if p.exists():
        print(f'OK: {p}')
    else:
        warnings.warn(f'Path does not exist: {p}')

# %%
# TODO: Load processed precipitation NetCDF with xarray and plot a domain map
# using cartopy showing mean annual precipitation over cfg['domain'].
raise NotImplementedError('TODO')

# %%
# TODO: Plot monthly climatology and interannual variability for each sub-region
# defined in cfg['regions']. Overlay the extreme-event threshold derived from
# cfg['extreme_precip_percentile'].
raise NotImplementedError('TODO')
