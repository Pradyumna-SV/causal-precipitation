# %% [markdown]
# # 03 — Stationarity Analysis
#
# **Owner:** Anirudh
#
# **Purpose:** Test all region-averaged time series for stationarity before running causal discovery. Apply the Augmented Dickey–Fuller (ADF) test to each variable and region combination, and decide on differencing or detrending strategies as needed.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path('..') / 'src'))

from causal_precip import load_config
import pprint

cfg = load_config()
pprint.pprint(cfg)

# %%
import warnings

processed_path = Path('..') / cfg['paths']['processed']

if processed_path.exists():
    print(f'OK: {processed_path}')
else:
    warnings.warn(f'Processed data path does not exist: {processed_path}')

# %%
# TODO: Load region-averaged time series for all variables from processed_path.
# Run the ADF test (from statsmodels) on each series and collect p-values.
# Display a summary table: region × variable × ADF statistic × p-value × verdict.
raise NotImplementedError('TODO')

# %%
# TODO: For any non-stationary series, apply first-order differencing and re-run
# the ADF test. Plot the original and differenced series side by side for visual
# inspection. Document the chosen transformation for each variable.
raise NotImplementedError('TODO')
