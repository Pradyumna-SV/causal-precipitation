# %% [markdown]
# # 02 — Exploratory Data Analysis: SST and ENSO
#
# **Owner:** Suditi
#
# **Purpose:** Explore sea-surface temperature anomalies over the study period and quantify their relationship with the ONI (Oceanic Niño Index). Correlate the Niño 3.4 regional average with downstream precipitation anomalies to motivate the causal graph structure.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path('..') / 'src'))

from causal_precip import load_config
import pprint

cfg = load_config()
pprint.pprint(cfg)

# %%
import warnings

raw_path = Path('..') / cfg['paths']['raw_data']
processed_path = Path('..') / cfg['paths']['processed']

for p in [raw_path, processed_path]:
    if p.exists():
        print(f'OK: {p}')
    else:
        warnings.warn(f'Path does not exist: {p}')

# %%
# TODO: Compute the Niño 3.4 SST anomaly index using the region defined in
# cfg['nino34_region'] and plot it alongside the canonical ONI time series.
raise NotImplementedError('TODO')

# %%
# TODO: Compute lag-correlations between the Niño 3.4 index and region-averaged
# precipitation for each sub-region in cfg['regions']. Plot as a heatmap with
# lags 0-12 months on the x-axis.
raise NotImplementedError('TODO')
